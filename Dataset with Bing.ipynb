# %%
# !pip install bing-image-downloader
# Out:
# ...
# [notice] A new release of pip available: 23.0.1 -> 24.0
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# !mkdir cats

# %%
from bing_image_downloader import downloader
downloader.download("cats", limit=200,  output_dir='cats', adult_filter_off=True, timeout=60)
# Out:
# [%] Downloading Images to C:\Users\AJAY\Desktop\Major project\cats\cats
#
#
# [!!]Indexing page: 1
#
# [%] Indexed 35 Images on Page 1.
#
# ...
#
# [%] Downloading Image #1 from http://images6.fanpop.com/image/photos/39000000/Cat-cats-39082303-1680-1050.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #2 from http://4.bp.blogspot.com/-cqPd-frMgAQ/UQ_owKgdamI/AAAAAAAAAHg/BkL1Vrn0jHg/s1600/08474-Cute-kittens-with-fringed-cover.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #3 from https://cdn.pixabay.com/photo/2017/05/29/15/34/kitten-2354016_1280.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #4 from http://www.phlmetropolis.com/Cats.jpg
# [Error]Invalid image, not saving http://www.phlmetropolis.com/Cats.jpg
#
# [!] Issue getting: http://www.phlmetropolis.com/Cats.jpg
# [!] Error:: Invalid image, not saving http://www.phlmetropolis.com/Cats.jpg
#
# [%] Downloading Image #4 from http://cooltickling.com/wp-content/uploads/2010/12/cat2.jpg
# [%] File Downloaded !
#
# ...

# %%
# !mkdir dogs

# %%
from bing_image_downloader import downloader
downloader.download("dogs", limit=200,  output_dir='dogs', adult_filter_off=True, timeout=60)
# Out:
# [%] Downloading Images to C:\Users\AJAY\Desktop\Major project\dogs\dogs
#
#
# [!!]Indexing page: 1
#
# [%] Indexed 35 Images on Page 1.
#
# ...
#
# [%] Downloading Image #1 from https://3.bp.blogspot.com/-OukFe37JYNs/UOgOYK-e06I/AAAAAAAABLY/Jjzbht9nA9g/s1600/89663-wallpapers-cute-dogs.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #2 from https://www.thesprucepets.com/thmb/rAbj4fO696TL2EPGyr7Q6TLQy1c=/1500x1000/filters:fill(auto,1)/GettyImages-977898246-1942d4364fa64bd2ba792a86f4f24715.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #3 from http://norfolkterrier.org/wp-content/uploads/2012/10/img_6096-1.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #4 from https://www.wallpaperup.com/uploads/wallpapers/2012/08/04/8076/2e659af0b4d60cdc7ec39f7332a20389.jpg
# [!] Issue getting: https://www.wallpaperup.com/uploads/wallpapers/2012/08/04/8076/2e659af0b4d60cdc7ec39f7332a20389.jpg
# ...
